# %%
import pandas as pd

# %%
df=pd.read_csv('D:\IPL1.csv')

# %%
df1=pd.read_csv('D:\IPL.csv')

# %%
df.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
df.dismissal_kind.unique()
# Out:
# array([nan, 'caught', 'run out', 'bowled', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field'], dtype=object)

# %%
df.dismissal_kind.fillna('notout',inplace=True)

# %%
df.dismissal_kind.isnull().sum()
# Out:
# 0

# %%
df.player_dismissed.unique()
# Out:
# array([nan, 'RT Ponting', 'DJ Hussey', 'SC Ganguly', 'MV Boucher',
#        'B Akhil', 'CL White', 'AA Noffke', 'Z Khan', 'SB Joshi',
#        'JH Kallis', 'W Jaffer', 'R Dravid', 'V Kohli', 'SK Raina',
#        'JDP Oram', 'PA Patel', 'ML Hayden', 'MS Dhoni', 'JR Hopes',
#        'Yuvraj Singh', 'KC Sangakkara', 'K Goel', 'SK Warne', 'V Sehwag',
#        'T Kohli', 'YK Pathan', 'SR Watson', 'DS Lehmann', 'M Kaif',
#        'M Rawat', 'RA Jadeja', 'DJ Thornely', 'L Ronchi', 'ST Jayasuriya',
#        'PR Shah', 'RV Uthappa', 'AM Nayar', 'SM Pollock', 'S Chanderpaul',
#        'LRPL Taylor', 'BB McCullum', 'WP Saha', 'AS Yadav', 'A Symonds',
#        'WPUJC Vaas', 'SB Bangar', 'PP Ojha', 'Y Venugopal Rao',
#        'VVS Laxman', 'AC Gilchrist', 'RG Sharma', 'SB Styris',
#        'Mohammad Hafeez', 'Kamran Akmal', 'DPMD Jayawardene', 'IK Pathan',
#        'B Lee', 'S Sohal', 'G Gambhir', 'Shahid Afridi', 'MEK Hussey',
#        'Harbhajan Singh', 'DJ Bravo', 'MA Khote', 'GC Smith',
# ...

# %%
df.player_dismissed.isnull().sum()
# Out:
# 183973

# %%
df.player_dismissed.fillna('notout',inplace=True)

# %%
df.fielder.fillna('no fielder',inplace=True)

# %%
df.extras_type.fillna('no runs',inplace=True)

# %%
df.bowling_team.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kolkata Knight Riders',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df1.city.fillna(df1['venue'],inplace=True)

# %%
df1.winner.isnull().sum()
# Out:
# 4

# %%
df1['winner'].fillna(df1['result'], inplace = True)
df1['player_of_match'].fillna(df1['result'], inplace = True)
df1['umpire1'].fillna('unknown', inplace = True)
df1['umpire2'].fillna('unknown', inplace = True)

# %%
df1.date
# Out:
# 0      2008-04-18
# 1      2008-04-19
# 2      2008-04-19
# 3      2008-04-20
# 4      2008-04-20
#           ...
# 811    2020-09-28
# 812    2020-11-05
# 813    2020-11-06
# 814    2020-11-08
# 815    2020-11-10
# Name: date, Length: 816, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
df1.winner
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 816, dtype: object

# %%
df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#    index      id        city        date player_of_match  \
# 0      0  335982   Bangalore  2008-04-18     BB McCullum
# 1      1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2      2  335984       Delhi  2008-04-19     MF Maharoof
# 3      3  335985      Mumbai  2008-04-20      MV Boucher
# 4      4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df1["season"] = df1["date"].apply(lambda x:x.split("-")[0])

# %%
df1.head()
# Out:
#    index      id        city        date player_of_match  \
# 0      0  335982   Bangalore  2008-04-18     BB McCullum
# 1      1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2      2  335984       Delhi  2008-04-19     MF Maharoof
# 3      3  335985      Mumbai  2008-04-20      MV Boucher
# 4      4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
data = pd.merge(left=df, right=df1, on='id', how='right')
data.head()
# Out:
#        id  inning  over  ball      batsman  non_striker     bowler  \
# 0  335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1  335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2  335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3  335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4  335982       1     7     3   RT Ponting  BB McCullum     Z Khan
#
#    batsman_runs  extra_runs  total_runs  ...                  toss_winner  \
# 0             1           0           1  ...  Royal Challengers Bangalore
# 1             1           0           1  ...  Royal Challengers Bangalore
# 2             0           0           0  ...  Royal Challengers Bangalore
# 3             1           0           1  ...  Royal Challengers Bangalore
# 4             1           0           1  ...  Royal Challengers Bangalore
#
#    toss_decision                 winner result result_margin eliminator  \
# ...

# %%
runs_by_years = data.groupby(by='season').sum()['total_runs']

# %%
runs_by_years
# Out:
# season
# 2008    17937
# 2009    16320
# 2010    18864
# 2011    21154
# 2012    22453
# 2013    22541
# 2014    18909
# 2015    18332
# 2016    18862
# 2017    18769
# 2018    19901
# 2019    19400
# 2020    19352
# Name: total_runs, dtype: int64

# %%
runs_by_years = pd.DataFrame(runs_by_years)
runs_by_years.reset_index(inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,9))
sns.lineplot(data=runs_by_years, x='season', y='total_runs')
plt.title('Runs scored over the years')
plt.show()

# %%
data.head()
# Out:
#        id  inning  over  ball      batsman  non_striker     bowler  \
# 0  335982       1     6     5   RT Ponting  BB McCullum  AA Noffke
# 1  335982       1     6     6  BB McCullum   RT Ponting  AA Noffke
# 2  335982       1     7     1  BB McCullum   RT Ponting     Z Khan
# 3  335982       1     7     2  BB McCullum   RT Ponting     Z Khan
# 4  335982       1     7     3   RT Ponting  BB McCullum     Z Khan
#
#    batsman_runs  extra_runs  total_runs  ...                  toss_winner  \
# 0             1           0           1  ...  Royal Challengers Bangalore
# 1             1           0           1  ...  Royal Challengers Bangalore
# 2             0           0           0  ...  Royal Challengers Bangalore
# 3             1           0           1  ...  Royal Challengers Bangalore
# 4             1           0           1  ...  Royal Challengers Bangalore
#
#    toss_decision                 winner result result_margin eliminator  \
# ...

# %%
sns.countplot(data=data, x='toss_decision')

# %%
runs_wickets_over=data.groupby(by='over').sum()

# %%
runs_wickets_over
# Out:
#               id  inning   ball  batsman_runs  extra_runs  total_runs  \
# over
# 0     7737270662   15380  37641          8894         910        9804
# 1     7727456899   15383  37671         10744         898       11642
# 2     7662159257   15235  36945         12259         746       13005
# 3     7633033562   15161  36662         12674         674       13348
# 4     7620029242   15122  36514         12798         607       13405
# 5     7596900091   15075  36424         12770         700       13470
# 6     7559153387   15001  36174         10205         635       10840
# 7     7539045409   14967  35982         10998         550       11548
# 8     7529733788   14918  35905         11448         551       11999
# 9     7507561726   14830  35611         11344         531       11875
# 10    7462464975   14752  35380         11728         471       12199
# 11    7438671896   14696  35314         11966         492       12458
# ...

# %%
runs_wickets_over=pd.DataFrame(runs_wickets_over[['total_runs','is_wicket']])

# %%
runs_wickets_over
# Out:
#       total_runs  is_wicket
# over
# 0           9804        318
# 1          11642        378
# 2          13005        403
# 3          13348        412
# 4          13405        416
# 5          13470        405
# 6          10840        327
# 7          11548        347
# 8          11999        393
# 9          11875        361
# 10         12199        417
# 11         12458        417
# 12         12542        405
# 13         12897        468
# 14         13326        475
# 15         13449        544
# 16         13989        572
# 17         14307        733
# 18         13804        750
# 19         12887        954

# %%
runs_wickets_over.reset_index(inplace=True)

# %%
runs_wickets_over
# Out:
#     over  total_runs  is_wicket
# 0      0        9804        318
# 1      1       11642        378
# 2      2       13005        403
# 3      3       13348        412
# 4      4       13405        416
# 5      5       13470        405
# 6      6       10840        327
# 7      7       11548        347
# 8      8       11999        393
# 9      9       11875        361
# 10    10       12199        417
# 11    11       12458        417
# 12    12       12542        405
# 13    13       12897        468
# 14    14       13326        475
# 15    15       13449        544
# 16    16       13989        572
# 17    17       14307        733
# 18    18       13804        750
# 19    19       12887        954

# %%
sns.scatterplot(data=runs_wickets_over,x='over',y='total_runs',size='is_wicket')

# %%
data.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'index', 'city', 'date',
#        'player_of_match', 'venue', 'neutral_venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'eliminator', 'method', 'umpire1', 'umpire2', 'season'],
#       dtype='object')

# %%
runs_overs = data.groupby(by='over').sum()

# %%
runs_overs=pd.DataFrame(runs_overs['total_runs'])

# %%
runs_overs.reset_index(inplace=True)

# %%
runs_overs
# Out:
#     over  total_runs
# 0      0        9804
# 1      1       11642
# 2      2       13005
# 3      3       13348
# 4      4       13405
# 5      5       13470
# 6      6       10840
# 7      7       11548
# 8      8       11999
# 9      9       11875
# 10    10       12199
# 11    11       12458
# 12    12       12542
# 13    13       12897
# 14    14       13326
# 15    15       13449
# 16    16       13989
# 17    17       14307
# 18    18       13804
# 19    19       12887

# %%
sns.scatterplot(data=runs_overs,x='over',y='total_runs')

# %%
runs_overs.plot(kind='hist',x='over',y='total_runs')

# %%
runs_match=data.groupby(by='id').sum()

# %%
runs_match=pd.DataFrame(runs_match['total_runs'])

# %%
runs_match.reset_index(inplace=True)

# %%
runs_match.plot(kind='hist',x='id',y='total_runs')

# %%
runs_match_year=data.groupby(by=['id','season']).sum()

# %%
runs_match_year=pd.DataFrame(runs_match_year['total_runs'])

# %%
runs_match_year.reset_index(inplace=True)

# %%
runs_match_year
# Out:
#           id season  total_runs
# 0     335982   2008         304
# 1     335983   2008         447
# 2     335984   2008         261
# 3     335985   2008         331
# 4     335986   2008         222
# ..       ...    ...         ...
# 811  1216547   2020         402
# 812  1237177   2020         343
# 813  1237178   2020         263
# 814  1237180   2020         361
# 815  1237181   2020         313
#
# [816 rows x 3 columns]

# %%
sns.countplot(data=data, x='total_runs')

# %%
plt.figure(figsize=(15,9))
sns.countplot(data=data, x='dismissal_kind')

# %%
data.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'index', 'city', 'date',
#        'player_of_match', 'venue', 'neutral_venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'eliminator', 'method', 'umpire1', 'umpire2', 'season'],
#       dtype='object')

# %%
data.is_wicket
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 193463    0
# 193464    0
# 193465    0
# 193466    0
# 193467    0
# Name: is_wicket, Length: 193468, dtype: int64

# %%
data.dismissal_kind.isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,112))
sns.countplot(y=data[data['dismissal_kind'] != 'notout']['bowler'],
              order=data[data['dismissal_kind'] != 'notout']['bowler'].value_counts().index)

# %%
data
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  ...  \
# 0             AA Noffke             1           0           1  ...
# 1             AA Noffke             1           0           1  ...
# ...

# %%
data.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'index', 'city', 'date',
#        'player_of_match', 'venue', 'neutral_venue', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin',
#        'eliminator', 'method', 'umpire1', 'umpire2', 'season'],
#       dtype='object')

# %%
a=data.groupby(by='player_of_match').sum()['total_runs']

# %%
a=a.sort_values(ascending=False)

# %%
a=pd.DataFrame(a)

# %%
a.reset_index(inplace=True)

# %%
a=a.loc[0:10]

# %%
a.plot(kind='bar',x='player_of_match',y='total_runs')

# %%
df=pd.read_csv('D:\IPL1.csv')

# %%
df.isnull().sum()
# Out:
# id                       0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
df1=pd.read_csv('D:\IPL.csv')

# %%
df1.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
b=df1[['player_of_match','winner']]

# %%
b.player_of_match.value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
#                   ..
# DJG Sammy          1
# S Aravind          1
# Imran Tahir        1
# P Parameswaran     1
# WPUJC Vaas         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
b=pd.DataFrame(b)

# %%
b
# Out:
#     player_of_match                       winner
# 0       BB McCullum        Kolkata Knight Riders
# 1        MEK Hussey          Chennai Super Kings
# 2       MF Maharoof             Delhi Daredevils
# 3        MV Boucher  Royal Challengers Bangalore
# 4         DJ Hussey        Kolkata Knight Riders
# ..              ...                          ...
# 811  AB de Villiers  Royal Challengers Bangalore
# 812       JJ Bumrah               Mumbai Indians
# 813   KS Williamson          Sunrisers Hyderabad
# 814      MP Stoinis               Delhi Capitals
# 815        TA Boult               Mumbai Indians
#
# [816 rows x 2 columns]

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df1.winner.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df1.winner.isnull().sum()
# Out:
# 4

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
df1.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df1[df1['player_of_match']=='BB McCullum']
# Out:
#          id       city        date player_of_match  \
# 0    335982  Bangalore  2008-04-18     BB McCullum
# 187  501210     Mumbai  2011-04-15     BB McCullum
# 192  501215      Kochi  2011-04-18     BB McCullum
# 461  829711    Chennai  2015-04-11     BB McCullum
# 482  829753    Chennai  2015-04-25     BB McCullum
#
#                                venue  neutral_venue  \
# 0              M Chinnaswamy Stadium              0
# 187                 Wankhede Stadium              0
# 192                    Nehru Stadium              0
# 461  MA Chidambaram Stadium, Chepauk              0
# 482  MA Chidambaram Stadium, Chepauk              0
#
#                            team1                  team2  \
# 0    Royal Challengers Bangalore  Kolkata Knight Riders
# 187               Mumbai Indians   Kochi Tuskers Kerala
# 192         Kochi Tuskers Kerala    Chennai Super Kings
# 461          Chennai Super Kings    Sunrisers Hyderabad
# ...

# %%
df1[df1['winner']=='Kolkata Knight Riders'].player_of_match
# Out:
# 0        BB McCullum
# 4          DJ Hussey
# 28        SC Ganguly
# 32        SC Ganguly
# 35     Shoaib Akhtar
#            ...
# 768      Shivam Mavi
# 776      LH Ferguson
# 787       KD Karthik
# 794       PJ Cummins
# 809     Shubman Gill
# Name: player_of_match, Length: 99, dtype: object

# %%
df1.loc[df1['winner']=='Chennai Super Kings'],['id','result']
# Out:
# (          id        city        date player_of_match  \
#  1     335983  Chandigarh  2008-04-19      MEK Hussey
#  7     335989     Chennai  2008-04-23       ML Hayden
#  11    335993     Chennai  2008-04-26        JDP Oram
#  14    335996   Bangalore  2008-04-28        MS Dhoni
#  27    336009       Delhi  2008-05-08        MS Dhoni
#  ..       ...         ...         ...             ...
#  770  1216506   Abu Dhabi  2020-11-01      RD Gaikwad
#  777  1216513       Dubai  2020-10-04       SR Watson
#  792  1216528       Dubai  2020-10-13       RA Jadeja
#  800  1216536       Dubai  2020-10-29      RD Gaikwad
#  808  1216544       Dubai  2020-10-25      RD Gaikwad
#
#                                            venue  neutral_venue  \
#  1    Punjab Cricket Association Stadium, Mohali              0
#  7               MA Chidambaram Stadium, Chepauk              0
#  11              MA Chidambaram Stadium, Chepauk              0
# ...

# %%
df1.head(1)
# Out:
#        id       city        date player_of_match                  venue  \
# 0  335982  Bangalore  2008-04-18     BB McCullum  M Chinnaswamy Stadium
#
#    neutral_venue                        team1                  team2  \
# 0              0  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen

# %%
df1.winner.value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df1.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2',
#        'season'],
#       dtype='object')

# %%
df1["season"] = df1["date"].apply(lambda x:x.split("-")[0])

# %%
df1.season.dtype
# Out:
# dtype('O')

# %%
df1[df1['season']=='2020'].player_of_match.value_counts()
# Out:
# KL Rahul          3
# AB de Villiers    3
# TA Boult          3
# RD Gaikwad        3
# MP Stoinis        2
# A Nortje          2
# SV Samson         2
# YS Chahal         2
# SA Yadav          2
# S Dhawan          2
# Q de Kock         2
# BA Stokes         2
# S Nadeem          1
# KS Williamson     1
# CJ Jordan         1
# JJ Bumrah         1
# AT Rayudu         1
# PP Shaw           1
# KA Pollard        1
# AR Patel          1
# RA Jadeja         1
# PJ Cummins        1
# WP Saha           1
# Shubman Gill      1
# V Kohli           1
# JC Buttler        1
# RG Sharma         1
# R Tewatia         1
# Sandeep Sharma    1
# Ishan Kishan      1
# SS Iyer           1
# PK Garg           1
# CH Gayle          1
# RA Tripathi       1
# MK Pandey         1
# Rashid Khan       1
# Mohammed Siraj    1
# KD Karthik        1
# CV Varun          1
# R Ashwin          1
# JM Bairstow       1
# SR Watson         1
# LH Ferguson       1
# Shivam Mavi       1
# ...

# %%
a=df[['bowler','extra_runs']]

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
a=df.groupby(by='bowler').sum()['total_runs']

# %%
a=pd.DataFrame(a)

# %%
a.reset_index(inplace=True)

# %%
a
# Out:
#      index          bowler  total_runs
# 0        0  A Ashish Reddy         400
# 1        1      A Chandila         245
# 2        2     A Choudhary         144
# 3        3     A Dananjaya          47
# 4        4      A Flintoff         106
# ..     ...             ...         ...
# 415    415      YA Abdulla         311
# 416    416       YK Pathan        1443
# 417    417       YS Chahal        2782
# 418    418    Yuvraj Singh        1091
# 419    419          Z Khan        2860
#
# [420 rows x 3 columns]

# %%
a.sort_values(by='total_runs',ascending=False)
# Out:
#               bowler  total_runs
# 276        PP Chawla        4330
# 133  Harbhajan Singh        4038
# 6           A Mishra        3913
# 99          DJ Bravo        3869
# 281         R Ashwin        3756
# ..               ...         ...
# 356          SN Khan           6
# 34         AM Rahane           5
# 359        SPD Smith           5
# 95         DA Warner           2
# 22      AC Gilchrist           0
#
# [420 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
a=df.groupby(by='bowler').count()['dismissal_kind']

# %%
a=pd.DataFrame(a)

# %%
a
# Out:
#                 dismissal_kind
# bowler
# A Ashish Reddy              19
# A Chandila                  11
# A Choudhary                  5
# A Dananjaya                  0
# A Flintoff                   2
# ...                        ...
# YA Abdulla                  15
# YK Pathan                   46
# YS Chahal                  124
# Yuvraj Singh                39
# Z Khan                     119
#
# [420 rows x 1 columns]
